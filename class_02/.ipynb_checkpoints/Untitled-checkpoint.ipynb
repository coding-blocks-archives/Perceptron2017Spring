# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
im = cv2.imread('./img.jpg')
print im.shape
img = im[1000:3000, 1200:2000, :]
# Out:
# (4160, 3120, 3)

# %%
plt.imshow(img)
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')

plt.show()

# %%
ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

kernel = np.ones((5,5),np.uint8)
thresh = cv2.erode(thresh, kernel, iterations=2)

plt.imshow(thresh, cmap='gray')
plt.show()

# %%
params = cv2.SimpleBlobDetector_Params()

# params.filterByArea = True
# params.minArea = 1
# params.maxArea = 1000
det = cv2.SimpleBlobDetector_create(params)

kp = det.detect(thresh)
print len(kp)
# Out:
# 0

# %%
print len(kp)
print thresh.shape

plt.figure(0)
plt.imshow(thresh)
for k in kp:
    print k.pt
    plt.scatter(k.pt[0], k.pt[1])
plt.show()
# Out:
# 2
# (2000, 800)
# (465.8963623046875, 243.2585906982422)
# (447.5, 222.0)
