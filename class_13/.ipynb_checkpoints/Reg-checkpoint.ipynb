# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import pandas as pd

import keras
from keras.layers import Dense, Convolution2D, Dropout, Flatten, MaxPooling2D, Activation
from keras.models import Sequential
from keras.utils import np_utils

# %%
ds = pd.read_csv('./train.csv')
data = ds.values[:5000]

# %%
print data.shape
X = data[:, 1:]/255.0
X = X.reshape((X.shape[0], 28, 28, 1))
y = np_utils.to_categorical(data[:, 0])

print X.shape, y.shape
# Out:
# (5000, 785)
# (5000, 28, 28, 1) (5000, 10)

# %%
plt.imshow(X[0].reshape((28, 28)), cmap='gray')
plt.show()

# %%
split = int(0.3 * X.shape[0])

X_train = X[:split]
X_val = X[split:]

y_train = y[:split]
y_val = y[split:]

print X_train.shape, X_val.shape
print y_train.shape, y_val.shape
# Out:
# (1500, 28, 28, 1) (3500, 28, 28, 1)
# (1500, 10) (3500, 10)

# %%
model = Sequential()

model.add(Convolution2D(32, 3, 3, input_shape=(28, 28, 1), activation='relu'))
model.add(Convolution2D(16, 3, 3, activation='relu'))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dropout(0.4))

model.add(Dense(512))
model.add(Dropout(0.25))
model.add(Activation('relu'))

model.add(Dense(10))
model.add(Activation('softmax'))

model.summary()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# convolution2d_34 (Convolution2D) (None, 26, 26, 32)    320         convolution2d_input_17[0][0]
# ____________________________________________________________________________________________________
# convolution2d_35 (Convolution2D) (None, 24, 24, 16)    4624        convolution2d_34[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_15 (MaxPooling2D)   (None, 12, 12, 16)    0           convolution2d_35[0][0]
# ____________________________________________________________________________________________________
# flatten_13 (Flatten)             (None, 2304)          0           maxpooling2d_15[0][0]
# ____________________________________________________________________________________________________
# dense_21 (Dense)                 (None, 512)           1180160     flatten_13[0][0]
# ____________________________________________________________________________________________________
# activation_19 (Activation)       (None, 512)           0           dense_21[0][0]
# ____________________________________________________________________________________________________
# dense_22 (Dense)                 (None, 10)            5130        activation_19[0][0]
# ____________________________________________________________________________________________________
# activation_20 (Activation)       (None, 10)            0           dense_22[0][0]
# ====================================================================================================
# Total params: 1,190,234
# Trainable params: 1,190,234
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
hist = model.fit(X_train, y_train,
                nb_epoch=15,
                shuffle=True,
                batch_size=100,
                validation_data=(X_val, y_val))
# Out:
# Train on 1500 samples, validate on 3500 samples
# Epoch 1/15
# 1500/1500 [==============================] - 0s - loss: 1.3488 - acc: 0.6360 - val_loss: 0.5434 - val_acc: 0.8320
# Epoch 2/15
# 1500/1500 [==============================] - 0s - loss: 0.4666 - acc: 0.8513 - val_loss: 0.4631 - val_acc: 0.8743
# Epoch 3/15
# 1500/1500 [==============================] - 0s - loss: 0.3253 - acc: 0.9013 - val_loss: 0.3414 - val_acc: 0.9043
# Epoch 4/15
# 1500/1500 [==============================] - 0s - loss: 0.2169 - acc: 0.9393 - val_loss: 0.3199 - val_acc: 0.9071
# Epoch 5/15
# 1500/1500 [==============================] - 0s - loss: 0.1396 - acc: 0.9613 - val_loss: 0.2952 - val_acc: 0.9200
# Epoch 6/15
# 1500/1500 [==============================] - 0s - loss: 0.0979 - acc: 0.9727 - val_loss: 0.2952 - val_acc: 0.9206
# Epoch 7/15
# 1500/1500 [==============================] - 0s - loss: 0.0611 - acc: 0.9873 - val_loss: 0.2838 - val_acc: 0.9234
# Epoch 8/15
# 1500/1500 [==============================] - 0s - loss: 0.0374 - acc: 0.9913 - val_loss: 0.2804 - val_acc: 0.9314
# Epoch 9/15
# 1500/1500 [==============================] - 0s - loss: 0.0213 - acc: 0.9960 - val_loss: 0.2888 - val_acc: 0.9334
# Epoch 10/15
# 1500/1500 [==============================] - 0s - loss: 0.0127 - acc: 0.9993 - val_loss: 0.2900 - val_acc: 0.9306
# Epoch 11/15
# 1500/1500 [==============================] - 0s - loss: 0.0086 - acc: 1.0000 - val_loss: 0.3033 - val_acc: 0.9363
# Epoch 12/15
# 1500/1500 [==============================] - 0s - loss: 0.0059 - acc: 1.0000 - val_loss: 0.3120 - val_acc: 0.9386
# Epoch 13/15
# 1500/1500 [==============================] - 0s - loss: 0.0040 - acc: 1.0000 - val_loss: 0.3156 - val_acc: 0.9374
# Epoch 14/15
# 1500/1500 [==============================] - 0s - loss: 0.0033 - acc: 1.0000 - val_loss: 0.3237 - val_acc: 0.9386
# Epoch 15/15
# 1500/1500 [==============================] - 0s - loss: 0.0022 - acc: 1.0000 - val_loss: 0.3385 - val_acc: 0.9357

# %%
th = hist.history

plt.figure(0)
plt.plot(th['loss'], 'b')
plt.plot(th['val_loss'], 'g')

plt.figure(1)
plt.plot(th['acc'], 'b')
plt.plot(th['val_acc'], 'g')
