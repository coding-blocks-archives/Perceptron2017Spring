# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.datasets import load_iris
from matplotlib import pyplot as plt
# %matplotlib inline
from pandas.tools.plotting import scatter_matrix

# %%
ds = load_iris()
data = ds.data

# %%
x = pd.DataFrame(data, columns=ds.feature_names)

# %%
scatter_matrix(x)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0e1617ccd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e16223f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e141205d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e140a2350>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0e14010150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e13f90310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e13f12190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e13ef3d90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0e13e77d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e13dcfad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e13d5bd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e13cdfbd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0e13c4ba90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e13bcdc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e13bb2b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e13b33f90>]], dtype=object)
